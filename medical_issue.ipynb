# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\SHRADDHA\Downloads\medical_disease_prediction_10000.csv")

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.head(15)
# Out:
#     Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0    23    Male  17.5            102           177          161         88
# 1    69    Male  31.1            118           256          147         92
# 2    61  Female  31.3            114           206          193         74
# 3    47  Female  23.9            105           162          253         68
# 4    47    Male  28.3            148           121          280         84
# 5    75  Female  25.0             90           136          126         59
# 6    23  Female  27.1            125            85          212         71
# 7    64    Male  20.8            101           102          308         88
# 8    31  Female  28.8            145           177          285        107
# 9    24    Male  18.6            158            76          308         88
# 10   53  Female  17.8            132           169          312         97
# ...

# %%
df.tail(10)
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 9990   39  Female  24.2            149           181          284         66
# 9991   32    Male  25.7            172           175          307        101
# 9992   79    Male  32.2             99           256          247         84
# 9993   29    Male  22.1             95           150          144         58
# 9994   82  Female  21.7            153           273          139         61
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
#      Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
df["Age"].unique()
# Out:
# array([23, 69, 61, 47, 75, 64, 31, 24, 53, 83, 67, 68, 66, 70, 52, 26, 74,
#        48, 51, 42, 30, 80, 44, 73, 54, 33, 55, 77, 22, 36, 60, 29, 41, 63,
#        49, 20, 28, 79, 82, 45, 39, 78, 71, 40, 62, 81, 38, 43, 37, 34, 27,
#        18, 65, 56, 25, 58, 32, 84, 21, 46, 72, 19, 35, 57, 59, 50, 76])

# %%
df[df["Age"]==31]
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 8      31  Female  28.8            145           177          285        107
# 51     31  Female  24.0            106           252          188         71
# 101    31    Male  22.5            135           220          231         67
# 223    31  Female  23.6            106           160          257         87
# 338    31  Female  19.9            167           253          205         61
# ...   ...     ...   ...            ...           ...          ...        ...
# 9736   31    Male  27.0            110           117          228         98
# 9790   31  Female  24.3            135           182          295         66
# 9955   31  Female  20.5             92           165          235         98
# 9970   31  Female  25.3            111           105          283         83
# 9976   31  Female  23.0            106           227          218         74
#
# ...

# %%
df['BloodPressure'].unique()
# Out:
# array([102, 118, 114, 105, 148,  90, 125, 101, 145, 158, 132, 130, 108,
#        124, 174,  93, 161, 104, 100, 115, 167, 172, 153, 103, 176,  96,
#        160,  98, 120, 139, 154, 112, 119, 107, 106, 142, 166,  91,  95,
#        138, 152, 121, 147, 165, 159, 162, 178, 143, 126, 122, 164, 116,
#        135, 131,  97, 117, 170, 180, 175, 149, 146, 144,  99, 109, 168,
#         92, 155, 133, 141, 128, 137, 173, 163, 110, 127, 136, 157, 171,
#        179, 134, 156, 140,  94, 123, 177, 151, 129, 111, 169, 113, 150])

# %%
df['Disease'].unique()
# Out:
# <StringArray>
# ['Healthy', 'Pre-Diabetes', 'Hypertension', 'Heart Disease', 'Diabetes']
# Length: 5, dtype: str

# %%
df["Disease"].value_counts()
# Out:
# Disease
# Healthy          6329
# Hypertension     1771
# Pre-Diabetes     1453
# Heart Disease     232
# Diabetes          215
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df[df['BMI']>20]
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# 5      75  Female  25.0             90           136          126         59
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.isna()
# Out:
#         Age  Gender    BMI  BloodPressure  GlucoseLevel  Cholesterol  \
# 0     False   False  False          False         False        False
# 1     False   False  False          False         False        False
# 2     False   False  False          False         False        False
# 3     False   False  False          False         False        False
# 4     False   False  False          False         False        False
# ...     ...     ...    ...            ...           ...          ...
# 9995  False   False  False          False         False        False
# 9996  False   False  False          False         False        False
# 9997  False   False  False          False         False        False
# 9998  False   False  False          False         False        False
# 9999  False   False  False          False         False        False
#
#       HeartRate  Smoking  Alcohol  PhysicalActivity  FamilyHistory  Disease
# ...

# %%
df.isnull()
# Out:
#         Age  Gender    BMI  BloodPressure  GlucoseLevel  Cholesterol  \
# 0     False   False  False          False         False        False
# 1     False   False  False          False         False        False
# 2     False   False  False          False         False        False
# 3     False   False  False          False         False        False
# 4     False   False  False          False         False        False
# ...     ...     ...    ...            ...           ...          ...
# 9995  False   False  False          False         False        False
# 9996  False   False  False          False         False        False
# 9997  False   False  False          False         False        False
# 9998  False   False  False          False         False        False
# 9999  False   False  False          False         False        False
#
#       HeartRate  Smoking  Alcohol  PhysicalActivity  FamilyHistory  Disease
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5011
# Female    4989
# Name: count, dtype: int64

# %%
df.drop(['Gender'], axis=1)
# Out:
#       Age   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate Smoking  \
# 0      23  17.5            102           177          161         88      No
# 1      69  31.1            118           256          147         92      No
# 2      61  31.3            114           206          193         74     Yes
# 3      47  23.9            105           162          253         68      No
# 4      47  28.3            148           121          280         84      No
# ...   ...   ...            ...           ...          ...        ...     ...
# 9995   49  27.1            177           183          268         59      No
# 9996   84  29.2            142           215          145         77      No
# 9997   41  22.8            177           265          133         71      No
# 9998   55  29.0            126           241          298         57      No
# 9999   59  32.2            151           162          225         93      No
#
# ...

# %%
df.drop(['BloodPressure', 'Cholesterol'], axis=1)
# Out:
#       Age  Gender   BMI  GlucoseLevel  HeartRate Smoking Alcohol  \
# 0      23    Male  17.5           177         88      No      No
# 1      69    Male  31.1           256         92      No      No
# 2      61  Female  31.3           206         74     Yes      No
# 3      47  Female  23.9           162         68      No      No
# 4      47    Male  28.3           121         84      No     Yes
# ...   ...     ...   ...           ...        ...     ...     ...
# 9995   49    Male  27.1           183         59      No      No
# 9996   84    Male  29.2           215         77      No     Yes
# 9997   41    Male  22.8           265         71      No      No
# 9998   55    Male  29.0           241         57      No      No
# 9999   59    Male  32.2           162         93      No      No
#
#      PhysicalActivity FamilyHistory       Disease
# 0              Medium            No       Healthy
# 1                High           Yes  Pre-Diabetes
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
df_object=df.select_dtypes(include='object')
# Out:
# C:\Users\SHRADDHA\AppData\Local\Temp\ipykernel_25344\1582884455.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_object=df.select_dtypes(include='object')

# %%
df_object.columns
# Out:
# Index(['Gender', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='str')

# %%
df_object
# Out:
#       Gender Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 0       Male      No      No           Medium            No       Healthy
# 1       Male      No      No             High           Yes  Pre-Diabetes
# 2     Female     Yes      No           Medium            No       Healthy
# 3     Female      No      No              Low            No       Healthy
# 4       Male      No     Yes             High            No       Healthy
# ...      ...     ...     ...              ...           ...           ...
# 9995    Male      No      No             High            No  Hypertension
# 9996    Male      No     Yes             High           Yes  Hypertension
# 9997    Male      No      No           Medium           Yes  Hypertension
# 9998    Male      No      No           Medium           Yes  Pre-Diabetes
# 9999    Male      No      No             High           Yes  Pre-Diabetes
#
# [10000 rows x 6 columns]

# %%
complete_data =pd.concat([df_object,df_object],axis=1)

# %%
complete_data
# Out:
#       Gender Smoking Alcohol PhysicalActivity FamilyHistory       Disease  \
# 0       Male      No      No           Medium            No       Healthy
# 1       Male      No      No             High           Yes  Pre-Diabetes
# 2     Female     Yes      No           Medium            No       Healthy
# 3     Female      No      No              Low            No       Healthy
# 4       Male      No     Yes             High            No       Healthy
# ...      ...     ...     ...              ...           ...           ...
# 9995    Male      No      No             High            No  Hypertension
# 9996    Male      No     Yes             High           Yes  Hypertension
# 9997    Male      No      No           Medium           Yes  Hypertension
# 9998    Male      No      No           Medium           Yes  Pre-Diabetes
# 9999    Male      No      No             High           Yes  Pre-Diabetes
#
#       Gender Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# ...

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
#pandas ka through filtering karna hai
df[df['HeartRate']<100]
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.Smoking.value_counts()
# Out:
# Smoking
# No     7027
# Yes    2973
# Name: count, dtype: int64

# %%
df[(df['Smoking']=='No') & (df['Disease']=='pre diabetes')& (df['HeartRate']>100)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, BMI, BloodPressure, GlucoseLevel, Cholesterol, HeartRate, Smoking, Alcohol, PhysicalActivity, FamilyHistory, Disease]
# Index: []

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df[(df['Age']==30)&(df['Disease']=='diabetes')& (df['HeartRate']<100)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, BMI, BloodPressure, GlucoseLevel, Cholesterol, HeartRate, Smoking, Alcohol, PhysicalActivity, FamilyHistory, Disease]
# Index: []

# %%
df[(df['Age']==30)&(df['Smoking']=='No')& (df['HeartRate']>10)]
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 71     30    Male  24.9            162           242          225        107
# 250    30  Female  25.1             92           106          296         91
# 252    30  Female  27.9             98           140          291         87
# 348    30  Female  23.8            173           213          171         61
# 391    30  Female  21.9            109           152          304        101
# ...   ...     ...   ...            ...           ...          ...        ...
# 9660   30    Male  18.8            133           185          252         57
# 9805   30  Female  24.4            152            96          183         67
# 9850   30    Male  28.7            143           142          280        106
# 9879   30  Female  19.0             92            94          238         91
# 9975   30  Female  23.7            177           140          260         73
#
# ...

# %%
df.query('Age==30 & Smoking=="No" & HeartRate>10')
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 71     30    Male  24.9            162           242          225        107
# 250    30  Female  25.1             92           106          296         91
# 252    30  Female  27.9             98           140          291         87
# 348    30  Female  23.8            173           213          171         61
# 391    30  Female  21.9            109           152          304        101
# ...   ...     ...   ...            ...           ...          ...        ...
# 9660   30    Male  18.8            133           185          252         57
# 9805   30  Female  24.4            152            96          183         67
# 9850   30    Male  28.7            143           142          280        106
# 9879   30  Female  19.0             92            94          238         91
# 9975   30  Female  23.7            177           140          260         73
#
# ...

# %%
# data ko save ka liya 
df.to_csv("clear_medical_diseases_prediction_1000.csv")

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
plt.plot(df["Gender"])
plt.show()

# %%
plt.scatter(df['BMI'],df['HeartRate'])
plt.show()

# %%
plt.hist(df['Smoking'])
plt.show()

# %%
sns.kdeplot(df['BloodPressure'])
plt.show()

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
a=[1,2,3,4,5,6,7]
label =["Age","Gender","BMI","GlucoseLevel","Cholesterol","HeartRate","Smoking"]
plt.pie(a,labels=label)
plt.show()

# %%
a=[1,2,3,4,5,6,7]
label =["Age","Gender","BMI","GlucoseLevel","Cholesterol","HeartRate","Smoking"]
plt.pie(a,labels=label, explode=[0.1,0,0,0,0,0,0])
plt.show()

# %%
a=[1,2,3,4,5,6,7]
label =["Age","Gender","BMI","GlucoseLevel","Cholesterol","HeartRate","Smoking"]
colors=["purple","black","yellow","pink","red","green","brown"]
plt.pie(a,labels=label, explode=[0.1,0,0,0,0,0,0],shadow=True, colors=colors,autopct='%1.1f%%')
plt.legand()    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 5
#       1 a=[1,2,3,4,5,6,7]
#       2 label =["Age","Gender","BMI","GlucoseLevel","Cholesterol","HeartRate","Smoking"]
#       3 colors=["purple","black","yellow","pink","red","green","brown"]
#       4 plt.pie(a,labels=label, explode=[0.1,0,0,0,0,0,0],shadow=True, colors=colors,autopct='%1.1f%%')
# ----> 5 plt.legand()
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'legand'
